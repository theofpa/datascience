# %%
library(ggplot2)
cz<-read.table("/Users/theofpa/Downloads/cz4.csv",sep=",",header=TRUE)
cz$datetime<-as.POSIXct(cz$start.time..unix.time., origin="1970-01-01")
ggplot( cz, aes(x=datetime, y=..count.., fill=asset)) + 
  geom_histogram(binwidth=600) + 
  scale_fill_hue(limits = names(head(sort(summary(cz$asset),decreasing = T),10))) +
  guides(fill=guide_legend(title="UPC CZ channels"))
# Out:
# Error in if (args[[1]]$name == "C_title" && !is.null(args[[2]])) {: missing value where TRUE/FALSE needed

# %%
sc <- sparkR.init("local")
# Out:
# Error in eval(expr, envir, enclos): could not find function "sparkR.init"
